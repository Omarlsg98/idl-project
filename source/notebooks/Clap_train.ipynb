# %%
# !git clone https://github.com/LAION-AI/CLAP.git
# Out:
# Cloning into 'CLAP'...
# remote: Enumerating objects: 4339, done.
# remote: Counting objects: 100% (15/15), done.
# remote: Compressing objects: 100% (14/14), done.
# remote: Total 4339 (delta 4), reused 4 (delta 1), pack-reused 4324
# Receiving objects: 100% (4339/4339), 6.97 MiB | 27.34 MiB/s, done.
# Resolving deltas: 100% (3208/3208), done.

# %%
# !pip install laion_clap==1.1.0 --quiet
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 56.3 MB/s eta 0:00:00

# %%
from google.colab import drive
drive.mount('./drive')
# Out:
# Drive already mounted at ./drive; to attempt to forcibly remount, call drive.mount("./drive", force_remount=True).

# %%
# !pip install pydub
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !pip install webdataset
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !pip install wandb
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !pip install awscli
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.1/4.1 MB 49.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 630.1/630.1 kB 33.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.6/79.6 kB 8.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.7/10.7 MB 53.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: rsa
#     Found existing installation: rsa 4.9
#     Uninstalling rsa-4.9:
#       Successfully uninstalled rsa-4.9
#   Attempting uninstall: PyYAML
#     Found existing installation: PyYAML 6.0
#     Uninstalling PyYAML-6.0:
#       Successfully uninstalled PyYAML-6.0
# ...

# %%
config = {
    'batch_size': 96, 
    'lr': 1e-4, 
    'wd': 0.0, 
    'epochs': 45
}

# %%
import wandb
wandb.login(key="cce3530b8ee00a25da9393f98f6b0142435348a3") #API Key is in your wandb account, under settings (wandb.ai/settings)
# Out:
# wandb: W&B API key is configured. Use `wandb login --relogin` to force relogin
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# True

# %%
run = wandb.init(
    name = "10.16-clap-dataset-2#-htsat-roberta-fusion-", ## Wandb creates random run names if you skip this field
    reinit = True, ### Allows reinitalizing runs when you re-run this cell
    #id = 'vo24kiuj', #Insert specific run id here if you want to resume a previous run
    #resume = "must", ### You need this to resume previous runs, but comment out reinit = True when using this
    project = "project", ### Project should be created in your wandb account 
    config = config ### Wandb Config for your run
)
# Out:
# Tracking run with wandb version 0.14.0
# Run data is saved locally in <code>/content/wandb/run-20230401_014112-oh53078f</code>
# Syncing run <strong><a href='https://wandb.ai/cmu-idl/project/runs/oh53078f' target="_blank">10.16-clap-dataset-2#-htsat-roberta-fusion</a></strong> to <a href='https://wandb.ai/cmu-idl/project' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/cmu-idl/project' target="_blank">https://wandb.ai/cmu-idl/project</a>
#  View run at <a href='https://wandb.ai/cmu-idl/project/runs/oh53078f' target="_blank">https://wandb.ai/cmu-idl/project/runs/oh53078f</a>

# %%
# !chmod +x  /content/CLAP/experiment_scripts/train-only-clotho.sh

# %%
# !/content/CLAP/experiment_scripts/train-only-clotho.sh
# Out:
# 2023-04-24 05:10:44.655648: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2023-04-24,05:10:45 | INFO | Running with a single process. Device cpu.
# 2023-04-24,05:10:45 | INFO | openai cache dir: /root/.cache/clip
# 2023-04-24,05:10:45 | INFO | Loading HTSAT-tiny model config.
# /usr/local/lib/python3.9/dist-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3483.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# loading configuration file config.json from cache at /root/.cache/huggingface/hub/models--roberta-base/snapshots/bc2764f8af2e92b6eb5679868df33e224075ca68/config.json
# Model config RobertaConfig {
#   "architectures": [
#     "RobertaForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": 0,
#   "classifier_dropout": null,
# ...

# %%
# !python /content/CLAP/src/tests/data_loader_test.py
# Out:
# Traceback (most recent call last):
#   File "/content/CLAP/src/tests/data_loader_test.py", line 1, in <module>
#     from laion_clap import create_model
# ImportError: cannot import name 'create_model' from 'laion_clap' (/usr/local/lib/python3.9/dist-packages/laion_clap/__init__.py)

# %%
import laion_clap 
model = laion_clap.CLAP_Module(enable_fusion=False)
model.load_ckpt()
# Out:
# ...
# /usr/local/lib/python3.9/dist-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3483.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# ...
# Some weights of the model checkpoint at roberta-base were not used when initializing RobertaModel: ['lm_head.bias', 'lm_head.layer_norm.weight', 'lm_head.dense.weight', 'lm_head.layer_norm.bias', 'lm_head.dense.bias', 'lm_head.decoder.weight']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# ...

# %%
import numpy as np


audio_file = [
    "/content/drive/MyDrive/Project/YT Flac/_1woPC5HWSg.flac", 
    "/content/drive/MyDrive/Project/YT Flac/_0-2meOf9qY.flac",
    ]

captions = ["The low quality recording features a live performance of a rock song and it consists of a distorted male vocal singing over repetitive electric guitar melody, groovy bass and energetic drums. It sounds crushed, distorted, loud, but it is barely audible, as it was recorded with a poor quality microphone.", 
    "This music is an electronic guitar instrumental. The tempo is slow with a melancholic , resounding harmony on the guitar. It is mellow, soft, poignant, sentimental and emotional."
            ]
print(captions)
#text_embed = model.get_text_embedding(caption)
# Out:
# ['The low quality recording features a live performance of a rock song and it consists of a distorted male vocal singing over repetitive electric guitar melody, groovy bass and energetic drums. It sounds crushed, distorted, loud, but it is barely audible, as it was recorded with a poor quality microphone.', 'This music is an electronic guitar instrumental. The tempo is slow with a melancholic , resounding harmony on the guitar. It is mellow, soft, poignant, sentimental and emotional.']

# %%
fine_tune_model = laion_clap.CLAP_Module(enable_fusion=False)
fine_tune_model.load_ckpt('/content/drive/MyDrive/Project/2023_04_01-02_05_26-model_HTSAT-tiny-lr_0.0001-b_32-j_6-p_fp32/checkpoints/epoch_30.pt')

# %%
audio_embed = model.get_audio_embedding_from_filelist(x = audio_file) # audio_embed will be a numpy array with shape (N, 512)
print(audio_embed.shape)
text_embed = model.get_text_embedding(captions) # text_embed will be a numpy array with shape (N, 512)
# Out:
# /usr/local/lib/python3.9/dist-packages/torchaudio/transforms/_transforms.py:611: UserWarning: Argument 'onesided' has been deprecated and has no influence on the behavior of this module.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/torchvision/transforms/functional.py:1603: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   warnings.warn(
# (2, 512)

# %%
from sklearn.metrics.pairwise import cosine_similarity
for i in range(len(audio_embed)):
    text_embed_0 = text_embed[i].reshape(1, -1)
    audio_embed_0 = audio_embed[i].reshape(1, -1)
    print(cosine_similarity(audio_embed_0, text_embed_0))
# Out:
# [[0.24751867]]
# [[0.06502239]]

# %%
audio_embed = fine_tune_model.get_audio_embedding_from_filelist(x = audio_file) # audio_embed will be a numpy array with shape (N, 512)
print(audio_embed.shape)
text_embed = fine_tune_model.get_text_embedding(captions) # text_embed will be a numpy array with shape (N, 512)
# Out:
# /usr/local/lib/python3.9/dist-packages/laion_clap/hook.py:151: UserWarning: PySoundFile failed. Trying audioread instead.
#   audio_waveform, _ = librosa.load(f, sr=48000)
# /usr/local/lib/python3.9/dist-packages/librosa/core/audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# /usr/local/lib/python3.9/dist-packages/laion_clap/hook.py:151: UserWarning: PySoundFile failed. Trying audioread instead.
#   audio_waveform, _ = librosa.load(f, sr=48000)
# /usr/local/lib/python3.9/dist-packages/librosa/core/audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# ...

# %%
from sklearn.metrics.pairwise import cosine_similarity
for i in range(len(audio_embed)):
    text_embed_0 = text_embed[i].reshape(1, -1)
    audio_embed_0 = audio_embed[i].reshape(1, -1)
    print(cosine_similarity(audio_embed_0, text_embed_0))
# Out:
# [[0.07523528]]
# [[0.2347563]]
# [[-0.20445429]]
# [[-0.14080027]]
